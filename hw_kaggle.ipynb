# %% [markdown]
# # Домашнее задание. Решение конкурса на kaggle.com
#
# Это домашнее задание посвящено полноценному решению задачи машинного обучения.

# %% [markdown]
# Есть две части этого домашнего задания:
#
# ### Отправить ваши предсказания в Stepik.
# За прохождение определенных порогов будут начисляться баллы. Эта часть оценивается из 5 баллов.
#
# 1) $1.00 \geqslant score \geqslant 0.84$ --- 5 баллов
#
# 2) $0.84 > score \geqslant 0.77$ --- 4 балла
#
# 3) $0.77 > score \geqslant 0.70$ --- 3 балла
#
# 4) $0.70 > score \geqslant 0.65$ --- 2 балла
#
# 5) $0.65 > score \geqslant 0.6$ --- 1 балл
#
# 6) $0.60 > score$ --- 0 баллов
#
# Для этого мы предварительно разделили данные в задании на две части.
# * `train.csv`. На этом наборе данных вам необходимо создать и обучить модель. Подробное описание файла есть в ноутбуке.
# * `test.csv`. В каждой строчке файла `test.csv` указаны признаки тестовых объектов. Предсказания для этого набора необходимо записать в файл submission.csv и сдать в соответствующий шаг на Stepik. Количество попыток ограничено 100 штук.
#
# Отправлять в Stepik вы будете файл с ответами `my_submission.csv`. В этом файле вам необходимо для каждого объекта из датасета предсказать вероятность класса 1. Мы подготовили для вас файл с примером посылки `submission.csv`. Ваш файл должен быть оформлен таким же образом. В ноутбуке есть пример оформления файла посылки. Для отправки файла с предсказаниями на Stepik есть отдельный шаг.
#
# ### Сделать полноценный отчет о вашей работе.
# Опишите, как вы обработали данные, какие модели попробовали и какие результаты получились (максимум 10 баллов). За каждую выполненную часть будет начислено определенное количество баллов. В этом пункте вам необходимо отправить файл в формате .ipynb на Stepik --- для этого в домашнем задании есть отдельный шаг. Этот пункт оценивается из 10 баллов.
#
# **Вторая часть будет проверяться в формате peer-review. Т.е. вашу посылку на Stepik будут проверять 3 других студента, и медианное значение их оценок будет выставлено. Чтобы получить баллы, вам также нужно будет проверить трех других учеников. Это станет доступно после того, как вы сдадите задание сами.**
#
# ### Контест на Kaggle
# Для вашего удобства мы подготовили [контест на Kaggle](https://www.kaggle.com/c/advanced-dls-spring-2021/). Тестирующая система на Kaggle выдает те же баллы, что и Stepik. Мы рекомендуем в качестве основной тестирующей системы использовать именно Kaggle, а затем сдать лучшую посылку на Stepik. Так вы привыкните работать с Kaggle.
#
# Проблема для российских пользователей Kaggle заключается в том, что подтверждение аккаунта по номеру телефона работает с перебоями или не работает вообще. Без подтвержденного номера телефона вы не сможете совершать посылки в kaggle. Если у вас возникла такая проблема, мы советуем следующие шаги:
# * Попробовать зарегистрировать аккаунт с аутентификацией через gmail. В таком случае, аккаунт должен работать без подтверждения номера телефона.
# * Если у вас есть не российский номер, используйте его для верификации аккаунта.
# * Если на номер телефона не приходит смс для верификации аккаунта, обратитесь в службу поддержки kaggle. Они с переменным успехом умеют подтверждать аккаунты вручную.
# * Если все же подтвердить аккаунт и получить доступ к сдаче заданий не удалось, используйте только сдачу в Stepik.
#
# ### Несколько замечаний по выполнению работы
# * Во всех пунктах указания это минимальный набор вещей, которые стоит сделать. Если вы можете сделать какой-то шаг лучше или добавить что-то свое --- дерзайте!
# * Пожалуйста, перед сдачей ноутбука убедитесь, что работа чистая и понятная. Это значительно облегчит проверку и повысит ваши ожидаемые баллы.
# * Если у вас будут проблемы с решением или хочется совета, то пишите в наш чат в телеграме.
#
#
# Данные: [train.csv](https://drive.google.com/file/d/1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K/view?usp=share_link),
# [test.csv](https://drive.google.com/file/d/1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r/view?usp=share_link), [submission.csv](https://drive.google.com/file/d/199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y/view?usp=share_link).
#
# Если ссылки на данные не работают, их можно скачать [на Kaggle](https://www.kaggle.com/competitions/advanced-dls-spring-2021/data).

# %% [markdown]
# # Как проверять?
#
# Ставьте полный балл, если выполнены все рекомендации или сделано что-то более интересное и сложное. За каждый отсустствующий пункт из рекомендации снижайте 1 балл.
#
# **Если решение верное, но не удовлетворяет вашим эстетическим предпочтениям, за это баллы снижать не нужно.**

# %% [markdown]
# # Метрика
#
# Перед решением любой задачи важно понимать, как будет оцениваться ваше решение. В данном случае мы используем стандартную для задачи классификации метрику ROC-AUC. Ее можно вычислить, используя только предсказанные вероятности и истинные классы без конкретного порога классификации + она раотает даже если классы в данных сильно несбалансированны (примеров одного класса в десятки раз больше примеров длугого). Именно поэтому она очень удобна для соревнований.
#
# Посчитать ее легко:

# %%
from sklearn.metrics import roc_auc_score

y_true = [
    0,
    1,
    1,
    0,
    1
]

y_predictions = [
    0.1,
    0.9,
    0.4,
    0.6,
    0.61
]

roc_auc_score(y_true, y_predictions)
# Out:
# 0.8333333333333333

# %% [markdown]
# # Первая часть. Исследование

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Загрузка данных (2 балла)
#
# 1) Посмотрите на случайные строчки.
#
# 2) Посмотрите, есть ли в датасете незаполненные значения (nan'ы) с помощью data.isna() или data.info() и, если нужно, замените их на что-то. Будет хорошо, если вы построите табличку с количеством nan в каждой колонке.

# %%
# !gdown 1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K  # train.csv
# !gdown 1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r  # test.csv
# !gdown 199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y  # submission.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K
# To: /content/train.csv
# 100% 664k/664k [00:00<00:00, 87.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r
# To: /content/test.csv
# 100% 218k/218k [00:00<00:00, 61.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y
# To: /content/submission.csv
# 100% 14.7k/14.7k [00:00<00:00, 16.3MB/s]

# %%
data = pd.read_csv('./train.csv')

# %%
# Для вашего удобства списки с именами разных колонок

# Числовые признаки
num_cols = [
    'ClientPeriod',
    'MonthlySpending',
    'TotalSpent'
]

# Категориальные признаки
cat_cols = [
    'Sex',
    'IsSeniorCitizen',
    'HasPartner',
    'HasChild',
    'HasPhoneService',
    'HasMultiplePhoneNumbers',
    'HasInternetService',
    'HasOnlineSecurityService',
    'HasOnlineBackup',
    'HasDeviceProtection',
    'HasTechSupportAccess',
    'HasOnlineTV',
    'HasMovieSubscription',
    'HasContractPhone',
    'IsBillingPaperless',
    'PaymentMethod'
]

feature_cols = num_cols + cat_cols
target_col = 'Churn'

# %%
# Проверяем на пустые ячейки
(data == ' ').any()

data['TotalSpent'].replace(' ', 0, inplace=True)
# # Заменяем пустые ячейки в Total Spent на NaN
# data['TotalSpent'].replace(' ', np.nan, inplace=True)

# # Удаляем NaN из датасета
# data.dropna(inplace=True)

# %% [markdown]
# ## Анализ данных (3 балла)
#
# 1) Для численных призанков постройте гистограмму (*plt.hist(...)*) или boxplot (*plt.boxplot(...)*). Для категориальных посчитайте количество каждого значения для каждого признака. Для каждой колонки надо сделать *data.value_counts()* и построить bar диаграммы *plt.bar(...)* или круговые диаграммы *plt.pie(...)* (хорошо, елси вы сможете это сделать на одном гарфике с помощью *plt.subplots(...)*).
#
# 2) Посмотрите на распределение целевой переменной и скажите, являются ли классы несбалансированными.
#
# 3) (Если будет желание) Поиграйте с разными библиотеками для визуализации - *sns*, *pandas_visual_analysis*, etc.
#
# Второй пункт очень важен, потому что существуют задачи классификации с несбалансированными классами. Например, это может значить, что в датасете намного больше примеров 0 класса. В таких случаях нужно 1) не использовать accuracy как метрику 2) использовать методы борьбы с imbalanced dataset (обычно если датасет сильно несбалансирован, т.е. класса 1 в 20 раз меньше класса 0).

# %%
# data["TotalSpent"] = data.TotalSpent.fillna(0).astype(float)

patterns = {
    "No": 0,
    "No internet service": 0,
    "No phone service": 0,
    "Yes": 1,
    "Male": 0,
    "Female": 1,
    "DSL": 1,
    "Fiber optic": 2,
    "Month-to-month": 0,
    "One year": 1,
    "Two year": 2,
    "Credit card (automatic)": 0,
    "Bank transfer (automatic)": 1,
    "Mailed check": 2,
    "Electronic check": 3,
}

X_train = data.replace(patterns).drop(target_col, axis=1)
y_train = data[target_col]

# %%
# fig, axes = plt.subplots(5, 4, figsize=(25, 20))
# for ax, col in zip(axes.flatten(), data.columns):
#     ax.set_title(col)
#     if col in cat_cols or col == target_col:
#         ax.pie(data[col].value_counts(), autopct="%1.1f%%", labels=data[col].value_counts().index)
#     else:
#         data[col].plot(kind="hist", ec="black", ax=ax)

# %% [markdown]
# (Дополнительно) Если вы нашли какие-то ошибки в данных или выбросы, то можете их убрать. Тут можно поэксперементировать с обработкой данных как угодно, но не за баллы.

# %%
sns.pairplot(data[num_cols])

# %%
data[num_cols].corr(method='spearman')
# Out:
#                  ClientPeriod  MonthlySpending
# ClientPeriod         1.000000         0.276906
# MonthlySpending      0.276906         1.000000

# %%
sns.heatmap(data[num_cols].corr(method='spearman'))
# Out:
# <Axes: >

# %%
sns.heatmap(data.corr(),
            annot=True,
            cmap="coolwarm",
            center=0,
            ax=plt.subplots(figsize=(15,10))[1]);

# %% [markdown]
# ## Применение линейных моделей (3 балла)
#
# 1) Обработайте данные для того, чтобы к ним можно было применить LogisticRegression. Т.е. отнормируйте числовые признаки, а категориальные закодируйте с помощью one-hot-encoding'а.
#
# 2) С помощью кроссвалидации или разделения на train/valid выборку протестируйте разные значения гиперпараметра C и выберите лучший (можно тестировать С=100, 10, 1, 0.1, 0.01, 0.001) по метрике ROC-AUC.
#
# Если вы разделяете на train/valid, то используйте LogisticRegressionCV. Он сам при вызове .fit() подберет параметр С. (не забудьте передать scroing='roc_auc', чтобы при кроссвалидации сравнивались значения этой метрики, и refit=True, чтобы при потом модель обучилась на всем датасете с лучшим параметром C).
#
#
# (более сложный вариант) Если вы будете использовать кроссвалидацию, то преобразования данных и LogisticRegression нужно соединить в один Pipeline с помощью make_pipeline, как это делалось во втором семинаре. Потом pipeline надо передать в GridSearchCV. Для one-hot-encoding'a можно испльзовать комбинацию LabelEncoder + OneHotEncoder (сначала превращаем строчки в числа, а потом числа првращаем в one-hot вектора.)

# %%
data['Sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# !pip install catboost
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: catboost in /usr/local/lib/python3.9/dist-packages (1.1.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost) (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost) (1.15.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.4.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost) (0.10.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (23.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (4.39.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.9/dist-packages (3.1.0)
# Requirement already satisfied: cmaes>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from optuna) (0.9.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.9/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (1.4.46)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna) (6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (1.10.2)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder, OneHotEncoder
# from sklearn.pipeline import make_pipeline

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import roc_auc_score

from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from optuna.samplers import TPESampler
from optuna.pruners import HyperbandPruner
from optuna.integration import CatBoostPruningCallback
import optuna

# %%
num_transformer = Pipeline([
    ('scaler', StandardScaler())
])

cat_transformer = Pipeline([
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_transformer, num_cols),])
        # ('cat', cat_transformer, cat_cols)])

regression_pipe = Pipeline([
    ('preprocess', preprocessor),
    ('model', LogisticRegression(max_iter=3000))
])

xgb_pipe = Pipeline([
    ('preprocess', preprocessor),
    ('model', XGBClassifier(objective='binary:logistic'))
])

cat_pipe = Pipeline([
    ('preprocess', preprocessor),
    ('model', CatBoostClassifier(cat_features=cat_cols,
    logging_level="Silent",
    eval_metric="AUC:hints=skip_train~false",
    grow_policy="Lossguide",
    metric_period=1000,
    random_seed=0))
])

# %%
C_OPTIONS = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
PENALTY = ['none', 'elasticnet', 'l1', 'l2']
SOLVER = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']

regression_parameters = {'model__solver': SOLVER,
              'model__penalty':PENALTY,
              'model__C':C_OPTIONS}

# %%
xgb_param = {'model__max_depth':np.arange(3, 10, 1),  
             'model__learning_rate':np.arange(0.1, 1, 0.1), 
             'model__tree_method':['hist'],
              'model__gamma': np.arange(0, 10, 0.5),
              'model__min_child_weight': np.arange(1, 10, 1),
             'model__n_estimators': np.arange(50, 200, 50)}

# %%
logreg = GridSearchCV(estimator = regression_pipe,  
                          param_grid = regression_parameters,
                          scoring = 'roc_auc',
                          cv = 5,
                          verbose=0)

# y = data[target_col]
# X = data[feature_cols]

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


# X_train = X
# y_train = y

# X_test = pd.read_csv('./test.csv')
# # Заменяем пустые ячейки в Total Spent на NaN
# X_test['TotalSpent'].replace(' ', 0, inplace=True)
# # Удаляем NaN из датасета
# X_test.dropna(inplace=True)

# %%
logreg.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
# ...
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 315 fits failed out of a total of 700.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 71, in _check_solver
#     raise ValueError("penalty='none' is not supported for the liblinear solver")
# ValueError: penalty='none' is not supported for the liblinear solver
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 64, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 1291, in fit
#     fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#   File "/usr/local/lib/python3.9/dist-packages/joblib/parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/usr/local/lib/python3.9/dist-packages/joblib/parallel.py", line 864, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/usr/local/lib/python3.9/dist-packages/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/usr/local/lib/python3.9/dist-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/usr/local/lib/python3.9/dist-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/usr/local/lib/python3.9/dist-packages/joblib/parallel.py", line 263, in __call__
#     return [func(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/joblib/parallel.py", line 263, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 521, in _logistic_regression_path
#     alpha = (1.0 / C) * (1 - l1_ratio)
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.80452751 0.80452751        nan 0.80452286 0.80452936        nan
#         nan        nan        nan        nan        nan        nan
#  0.5               nan 0.5        0.7958069  0.7958069  0.79695858
#  0.79580782 0.7958143  0.80452751 0.80452751        nan 0.80452936
#  0.8045275         nan        nan        nan        nan        nan
#         nan        nan 0.80343621        nan 0.80343713 0.80238698
#  0.80238698 0.80234998 0.80238143 0.80238698 0.80452751 0.80452751
#         nan 0.8045275  0.80452565        nan        nan        nan
#         nan        nan        nan        nan 0.8041526         nan
#  0.8041563  0.80403589 0.80403589 0.80396085 0.80403311 0.80404237
#  0.80452751 0.80452751        nan 0.80452658 0.80452843        nan
#         nan        nan        nan        nan        nan        nan
#  0.80439795        nan 0.80440537 0.80444704 0.80444704 0.80443871
#  0.80445167 0.80445074 0.80452751 0.80452751        nan 0.8045275
#  0.80452194        nan        nan        nan        nan        nan
#         nan        nan 0.80453398        nan 0.80453214 0.80453214
#  0.80453214 0.80453769 0.80453584 0.80453029 0.80452751 0.80452751
#         nan 0.80451914 0.80452286        nan        nan        nan
#         nan        nan        nan        nan 0.80452379        nan
#  0.80452101 0.80452194 0.80452194 0.80451916 0.80452472 0.80452194
#  0.80452751 0.80452751        nan 0.80452194 0.80452658        nan
#         nan        nan        nan        nan        nan        nan
#  0.80452101        nan 0.80452379 0.80452936 0.80452936 0.8045275
#  0.80452472 0.80453028]
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['ClientPeriod',
#                                                                           'MonthlySpending',
#                                                                           'TotalSpent'])])),
#                                        ('model',
#                                         LogisticRegression(max_iter=3000))]),
#              param_grid={'model__C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                          'model__penalty': ['none', 'elasticnet', 'l1', 'l2'],
#                          'model__solver': ['newton-cg', 'lbfgs', 'liblinear',
#                                            'sag', 'saga']},
#              scoring='roc_auc')

# %%
# results_df = pd.DataFrame(grid_search.cv_results_)
# results_df = results_df.sort_values(by=["rank_test_score"])
# results_df = results_df.set_index(
#     results_df["params"].apply(lambda x: "_".join(str(val) for val in x.values()))
# ).rename_axis("kernel")
# results_df[["params", "rank_test_score", "mean_test_score", "std_test_score"]]

# %%
# # получаем предказания
# lr_probs = logreg.predict_proba(X_test)

# # сохраняем вероятности только для положительного исхода
# lr_probs = lr_probs[:, 1]

# # рассчитываем ROC AUC
# lr_auc = roc_auc_score(y_test, lr_probs)

# %%
# получаем предказания
lr_probs = logreg.predict_proba(X_train)

# сохраняем вероятности только для положительного исхода
lr_probs = lr_probs[:, 1]

# рассчитываем ROC AUC
lr_auc = roc_auc_score(y_train, lr_probs)

# %%
lr_auc
# Out:
# 0.8049923519397822

# %%
xgb = GridSearchCV(estimator = xgb_pipe,  
                          param_grid = xgb_param,
                          scoring = 'roc_auc',
                          cv = 5,
                          verbose=0)

# %%
# xgb.fit(X_train, y_train)

# %%
# # получаем предказания
# lr_probs = logreg.predict_proba(X_train)

# # сохраняем вероятности только для положительного исхода
# lr_probs = lr_probs[:, 1]

# # рассчитываем ROC AUC
# lr_auc = roc_auc_score(y_train, lr_probs)

# %%
# lr_auc

# %% [markdown]
# Выпишите какое лучшее качество и с какими параметрами вам удалось получить

# %% [markdown]
# ## Применение градиентного бустинга (2 балла)
#
# Если вы хотите получить баллы за точный ответ, то стоит попробовать градиентный бустинг. Часто градиентный бустинг с параметрами по умолчанию даст вам 80% результата за 0% усилий.
#
# Мы будем использовать catboost, поэтому нам не надо кодировать категориальные признаки. Catboost сделает это сам (в .fit() надо передать cat_features=cat_cols). А численные признаки нормировать для моделей, основанных на деревьях не нужно.
#
# 1) Разделите выборку на train/valid. Протестируйте catboost cо стандартными параметрами.
#
# 2) Протестируйте разные занчения параметроа количества деревьев и learning_rate'а и выберите лучшую по метрике ROC-AUC комбинацию.
#
# (Дополнительно) Есть некоторые сложности с тем, чтобы использовать CatBoostClassifier вместе с GridSearchCV, поэтому мы не просим использовать кроссвалидацию. Но можете попробовать)

# %%
def objective(trial):

  cat_param = {
      "n_estimators": trial.suggest_int('n_estimators', 10, 1000),
      "learning_rate": trial.suggest_float('learning_rate', 0.0001, 0.5),
      "max_depth": trial.suggest_int('max_depth', 4, 16), 
      "l2_leaf_reg": trial.suggest_float('l2_leaf_reg', 0.1, 1), 
      # "subsample": trial.suggest_int('subsample', 3, 11),
      "random_strength": trial.suggest_int('random_strength', 1, 101),
      "min_data_in_leaf": trial.suggest_int('min_data_in_leaf', 10, 1000),
      "eval_metric": "AUC",

      "objective": trial.suggest_categorical("objective", ["Logloss", "CrossEntropy"]),
      "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1),
      "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
      "bootstrap_type": trial.suggest_categorical(
          "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        )}

  if cat_param["bootstrap_type"] == "Bayesian":
      cat_param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
  elif cat_param["bootstrap_type"] == "Bernoulli":
      cat_param["subsample"] = trial.suggest_float("subsample", 0.1, 1)


  model = CatBoostClassifier(**cat_param)


  pruning_callback = CatBoostPruningCallback(trial, "auc")
  # model.fit(X_train, y_train, eval_set=[(X_test, y_test)], cat_features=cat_cols, verbose=0, early_stopping_rounds=100)
  model.fit(X_train, y_train, cat_features=cat_cols, verbose=0, early_stopping_rounds=100)

  # preds = model.predict_proba(X_test)[:, 1]
  # score = roc_auc_score(y_test, preds)

  preds = model.predict_proba(X_train)[:, 1]
  score = roc_auc_score(y_train, preds)

  pruning_callback.check_pruned()  
  
  return score

# %%
sampler = TPESampler()
study = optuna.create_study(study_name="catboost", direction="maximize", sampler=sampler, pruner=optuna.pruners.HyperbandPruner())
# study = optuna.create_study(study_name="catboost", direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=100)
# Out:
# [I 2023-03-17 11:36:36,474] A new study created in memory with name: catboost
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:36:41,649] Trial 0 finished with value: 0.9211693709831927 and parameters: {'n_estimators': 353, 'learning_rate': 0.49654213689309545, 'max_depth': 13, 'l2_leaf_reg': 0.9638697638300325, 'random_strength': 69, 'min_data_in_leaf': 583, 'objective': 'Logloss', 'colsample_bylevel': 0.05085340386796335, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.9211693709831927.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:36:45,249] Trial 1 finished with value: 0.9261306005451143 and parameters: {'n_estimators': 623, 'learning_rate': 0.18018548537539078, 'max_depth': 9, 'l2_leaf_reg': 0.2134526641481843, 'random_strength': 58, 'min_data_in_leaf': 487, 'objective': 'Logloss', 'colsample_bylevel': 0.04624648239074798, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.9261306005451143.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:36:46,457] Trial 2 finished with value: 0.8768952397405517 and parameters: {'n_estimators': 367, 'learning_rate': 0.329236690086055, 'max_depth': 8, 'l2_leaf_reg': 0.4192175645440416, 'random_strength': 27, 'min_data_in_leaf': 162, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.03371144866226424, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.221114690452035}. Best is trial 1 with value: 0.9261306005451143.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:36:48,761] Trial 3 finished with value: 0.8532817147966795 and parameters: {'n_estimators': 421, 'learning_rate': 0.26505530851821396, 'max_depth': 13, 'l2_leaf_reg': 0.3751580380705025, 'random_strength': 11, 'min_data_in_leaf': 780, 'objective': 'Logloss', 'colsample_bylevel': 0.01576416372695342, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.033643565056341}. Best is trial 1 with value: 0.9261306005451143.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:36:51,213] Trial 4 finished with value: 0.8443804181483315 and parameters: {'n_estimators': 339, 'learning_rate': 0.002011925428264511, 'max_depth': 8, 'l2_leaf_reg': 0.6690332517842372, 'random_strength': 86, 'min_data_in_leaf': 743, 'objective': 'Logloss', 'colsample_bylevel': 0.06679019266970826, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.9261306005451143.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:36:55,987] Trial 5 finished with value: 0.8697898284877082 and parameters: {'n_estimators': 653, 'learning_rate': 0.16634415104158923, 'max_depth': 15, 'l2_leaf_reg': 0.902227668853974, 'random_strength': 10, 'min_data_in_leaf': 255, 'objective': 'Logloss', 'colsample_bylevel': 0.02940093623644468, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.9261306005451143.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:04,040] Trial 6 finished with value: 0.961919852184461 and parameters: {'n_estimators': 857, 'learning_rate': 0.40463784365780264, 'max_depth': 7, 'l2_leaf_reg': 0.4923205305191599, 'random_strength': 66, 'min_data_in_leaf': 700, 'objective': 'Logloss', 'colsample_bylevel': 0.09448325434108872, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 6 with value: 0.961919852184461.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:06,642] Trial 7 finished with value: 0.8609287555200977 and parameters: {'n_estimators': 827, 'learning_rate': 0.19551041997449917, 'max_depth': 12, 'l2_leaf_reg': 0.29459364891044054, 'random_strength': 31, 'min_data_in_leaf': 817, 'objective': 'Logloss', 'colsample_bylevel': 0.01818119733571376, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 6 with value: 0.961919852184461.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:10,898] Trial 8 finished with value: 0.8385537306815115 and parameters: {'n_estimators': 906, 'learning_rate': 0.020002125725076703, 'max_depth': 14, 'l2_leaf_reg': 0.4961778231856946, 'random_strength': 70, 'min_data_in_leaf': 248, 'objective': 'Logloss', 'colsample_bylevel': 0.01300535606733416, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5660211673281276}. Best is trial 6 with value: 0.961919852184461.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:12,148] Trial 9 finished with value: 0.8455840700878173 and parameters: {'n_estimators': 390, 'learning_rate': 0.15109993919162062, 'max_depth': 9, 'l2_leaf_reg': 0.2205589711695856, 'random_strength': 10, 'min_data_in_leaf': 901, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.013043064653075346, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 6 with value: 0.961919852184461.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:12,472] Trial 10 finished with value: 0.8766093179546647 and parameters: {'n_estimators': 95, 'learning_rate': 0.46440739710845613, 'max_depth': 5, 'l2_leaf_reg': 0.12299213368148848, 'random_strength': 99, 'min_data_in_leaf': 528, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09989715847017971, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9656895019943805}. Best is trial 6 with value: 0.961919852184461.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:15,384] Trial 11 finished with value: 0.930601268028365 and parameters: {'n_estimators': 671, 'learning_rate': 0.3749682417552977, 'max_depth': 4, 'l2_leaf_reg': 0.11202892799949157, 'random_strength': 53, 'min_data_in_leaf': 389, 'objective': 'Logloss', 'colsample_bylevel': 0.09278277764668383, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 6 with value: 0.961919852184461.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:19,585] Trial 12 finished with value: 0.9552291897134148 and parameters: {'n_estimators': 998, 'learning_rate': 0.38982976745249637, 'max_depth': 4, 'l2_leaf_reg': 0.1027087384124099, 'random_strength': 43, 'min_data_in_leaf': 22, 'objective': 'Logloss', 'colsample_bylevel': 0.09965319332851494, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 6 with value: 0.961919852184461.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:28,186] Trial 13 finished with value: 0.9550611585309793 and parameters: {'n_estimators': 978, 'learning_rate': 0.40848706815432884, 'max_depth': 6, 'l2_leaf_reg': 0.5654624199704423, 'random_strength': 38, 'min_data_in_leaf': 70, 'objective': 'Logloss', 'colsample_bylevel': 0.08530075319709646, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.20784404612797486}. Best is trial 6 with value: 0.961919852184461.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:31,797] Trial 14 finished with value: 0.9661451922877301 and parameters: {'n_estimators': 806, 'learning_rate': 0.425615180067231, 'max_depth': 6, 'l2_leaf_reg': 0.3514359447439468, 'random_strength': 45, 'min_data_in_leaf': 644, 'objective': 'Logloss', 'colsample_bylevel': 0.0807805104068353, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.9661451922877301.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:39,345] Trial 15 finished with value: 0.948832048894201 and parameters: {'n_estimators': 782, 'learning_rate': 0.44696757517752506, 'max_depth': 7, 'l2_leaf_reg': 0.6161105002989807, 'random_strength': 69, 'min_data_in_leaf': 992, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.07833350382238491, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.13434397182065982}. Best is trial 14 with value: 0.9661451922877301.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:45,088] Trial 16 finished with value: 0.9395178570898963 and parameters: {'n_estimators': 765, 'learning_rate': 0.335784031639372, 'max_depth': 6, 'l2_leaf_reg': 0.4554793049164874, 'random_strength': 57, 'min_data_in_leaf': 655, 'objective': 'Logloss', 'colsample_bylevel': 0.07247457113381349, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 14 with value: 0.9661451922877301.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:50,690] Trial 17 finished with value: 0.9771838122113904 and parameters: {'n_estimators': 544, 'learning_rate': 0.4954450390455134, 'max_depth': 11, 'l2_leaf_reg': 0.34803481800867186, 'random_strength': 84, 'min_data_in_leaf': 664, 'objective': 'Logloss', 'colsample_bylevel': 0.08475880207600062, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 17 with value: 0.9771838122113904.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:53,314] Trial 18 finished with value: 0.9746145014339651 and parameters: {'n_estimators': 549, 'learning_rate': 0.4982380551406622, 'max_depth': 11, 'l2_leaf_reg': 0.30492263553554544, 'random_strength': 88, 'min_data_in_leaf': 411, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.06414188802263782, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.10801549844002845}. Best is trial 17 with value: 0.9771838122113904.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:55,616] Trial 19 finished with value: 0.9613700667601882 and parameters: {'n_estimators': 523, 'learning_rate': 0.4911578746373314, 'max_depth': 11, 'l2_leaf_reg': 0.2922603123616904, 'random_strength': 86, 'min_data_in_leaf': 417, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.06303874175901766, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.13134689315257647}. Best is trial 17 with value: 0.9771838122113904.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:55,926] Trial 20 finished with value: 0.8875661929787618 and parameters: {'n_estimators': 137, 'learning_rate': 0.49842542290231356, 'max_depth': 16, 'l2_leaf_reg': 0.3595381257867397, 'random_strength': 101, 'min_data_in_leaf': 344, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.05870776060310321, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3612373130405555}. Best is trial 17 with value: 0.9771838122113904.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:37:59,534] Trial 21 finished with value: 0.9801926176755829 and parameters: {'n_estimators': 529, 'learning_rate': 0.4429949451573092, 'max_depth': 11, 'l2_leaf_reg': 0.31644148675392403, 'random_strength': 84, 'min_data_in_leaf': 625, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.07905047067826296, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4827257554075919}. Best is trial 21 with value: 0.9801926176755829.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:03,625] Trial 22 finished with value: 0.9761926784745104 and parameters: {'n_estimators': 547, 'learning_rate': 0.4442758451372021, 'max_depth': 11, 'l2_leaf_reg': 0.25249314520154353, 'random_strength': 86, 'min_data_in_leaf': 534, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.07058461539874263, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4669111305149329}. Best is trial 21 with value: 0.9801926176755829.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:06,038] Trial 23 finished with value: 0.9756065619837652 and parameters: {'n_estimators': 487, 'learning_rate': 0.44470303200798045, 'max_depth': 10, 'l2_leaf_reg': 0.21789890165472978, 'random_strength': 79, 'min_data_in_leaf': 560, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.07393932457339794, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5683841211537581}. Best is trial 21 with value: 0.9801926176755829.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:07,308] Trial 24 finished with value: 0.9675429188527095 and parameters: {'n_estimators': 217, 'learning_rate': 0.452415368311091, 'max_depth': 11, 'l2_leaf_reg': 0.41350583773278543, 'random_strength': 79, 'min_data_in_leaf': 853, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08127021747039083, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4433900565023214}. Best is trial 21 with value: 0.9801926176755829.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:14,341] Trial 25 finished with value: 0.9768344964217607 and parameters: {'n_estimators': 571, 'learning_rate': 0.3616742367159039, 'max_depth': 12, 'l2_leaf_reg': 0.2466337777237117, 'random_strength': 93, 'min_data_in_leaf': 634, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08801299742100092, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6750886786081847}. Best is trial 21 with value: 0.9801926176755829.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:18,884] Trial 26 finished with value: 0.9807371202662103 and parameters: {'n_estimators': 268, 'learning_rate': 0.35857781899458624, 'max_depth': 13, 'l2_leaf_reg': 0.1858231999918878, 'random_strength': 95, 'min_data_in_leaf': 648, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0874112227274133, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6896770212998387}. Best is trial 26 with value: 0.9807371202662103.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:24,921] Trial 27 finished with value: 0.9786842296479296 and parameters: {'n_estimators': 285, 'learning_rate': 0.4179832908424489, 'max_depth': 14, 'l2_leaf_reg': 0.17478090072548602, 'random_strength': 77, 'min_data_in_leaf': 734, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08851924937297109, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.122290005536817}. Best is trial 26 with value: 0.9807371202662103.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:29,802] Trial 28 finished with value: 0.9763438416617979 and parameters: {'n_estimators': 202, 'learning_rate': 0.33393871423422655, 'max_depth': 14, 'l2_leaf_reg': 0.1817185831642358, 'random_strength': 76, 'min_data_in_leaf': 904, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0904232957903672, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.249800016279058}. Best is trial 26 with value: 0.9807371202662103.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:32,267] Trial 29 finished with value: 0.9892593504301895 and parameters: {'n_estimators': 271, 'learning_rate': 0.41753475333637263, 'max_depth': 13, 'l2_leaf_reg': 0.16545162186336534, 'random_strength': 94, 'min_data_in_leaf': 741, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.07649559077665283, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.742938914418852}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:41,218] Trial 30 finished with value: 0.9764994535511022 and parameters: {'n_estimators': 446, 'learning_rate': 0.37286154209779165, 'max_depth': 16, 'l2_leaf_reg': 0.19826415810110223, 'random_strength': 94, 'min_data_in_leaf': 586, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.07495930629447076, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.9364854920913595}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:44,134] Trial 31 finished with value: 0.973268398348642 and parameters: {'n_estimators': 301, 'learning_rate': 0.4141894925379978, 'max_depth': 13, 'l2_leaf_reg': 0.15973483923949033, 'random_strength': 95, 'min_data_in_leaf': 721, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08091965359317753, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.575239662416147}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:50,452] Trial 32 finished with value: 0.9715248778831296 and parameters: {'n_estimators': 272, 'learning_rate': 0.4168941001404372, 'max_depth': 14, 'l2_leaf_reg': 0.16073179804505427, 'random_strength': 92, 'min_data_in_leaf': 474, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08709679545972805, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.251379514167946}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:50,672] Trial 33 finished with value: 0.884756188885956 and parameters: {'n_estimators': 29, 'learning_rate': 0.360000684107556, 'max_depth': 15, 'l2_leaf_reg': 0.1498671410648302, 'random_strength': 77, 'min_data_in_leaf': 780, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09206355256121346, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.716336783676179}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:51,020] Trial 34 finished with value: 0.8699961370437485 and parameters: {'n_estimators': 177, 'learning_rate': 0.3047769342949629, 'max_depth': 12, 'l2_leaf_reg': 0.26212149419383873, 'random_strength': 61, 'min_data_in_leaf': 606, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.04827057834515163, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.538513890920249}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:38:53,645] Trial 35 finished with value: 0.952676283524677 and parameters: {'n_estimators': 274, 'learning_rate': 0.3872789782532195, 'max_depth': 13, 'l2_leaf_reg': 0.17844605939615182, 'random_strength': 100, 'min_data_in_leaf': 753, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.053652987277816304, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.954238062341368}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:39:01,561] Trial 36 finished with value: 0.9699586567292549 and parameters: {'n_estimators': 343, 'learning_rate': 0.4696927960408789, 'max_depth': 15, 'l2_leaf_reg': 0.1059405950762897, 'random_strength': 72, 'min_data_in_leaf': 829, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0771073630340314, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.917586612515528}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:39:06,041] Trial 37 finished with value: 0.9629167321614464 and parameters: {'n_estimators': 444, 'learning_rate': 0.4265380683714345, 'max_depth': 14, 'l2_leaf_reg': 0.20948872401029667, 'random_strength': 63, 'min_data_in_leaf': 705, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.06883336636658684, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.5337031796185823}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:39:07,954] Trial 38 finished with value: 0.9760254814237033 and parameters: {'n_estimators': 245, 'learning_rate': 0.39339021555152115, 'max_depth': 10, 'l2_leaf_reg': 0.299630587003681, 'random_strength': 91, 'min_data_in_leaf': 500, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08352640366970275, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7423553831173388}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:39:14,388] Trial 39 finished with value: 0.9834873449256621 and parameters: {'n_estimators': 383, 'learning_rate': 0.3078278934251851, 'max_depth': 13, 'l2_leaf_reg': 0.24592782267100943, 'random_strength': 21, 'min_data_in_leaf': 989, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09581237868138849, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.99015829240511}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:39:17,210] Trial 40 finished with value: 0.9745111617933608 and parameters: {'n_estimators': 394, 'learning_rate': 0.2990182772752977, 'max_depth': 12, 'l2_leaf_reg': 0.3927020856710268, 'random_strength': 23, 'min_data_in_leaf': 969, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.07691683240967646, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7582369097730587}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:39:23,135] Trial 41 finished with value: 0.9843846851950162 and parameters: {'n_estimators': 313, 'learning_rate': 0.359011376196855, 'max_depth': 13, 'l2_leaf_reg': 0.2340921044910606, 'random_strength': 19, 'min_data_in_leaf': 791, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09475816936048849, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.957895115068098}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:39:28,756] Trial 42 finished with value: 0.9812589159402925 and parameters: {'n_estimators': 329, 'learning_rate': 0.35420791759944886, 'max_depth': 13, 'l2_leaf_reg': 0.2535701492871385, 'random_strength': 1, 'min_data_in_leaf': 917, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09522003067032855, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.375108348281193}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:39:35,668] Trial 43 finished with value: 0.9831569361196048 and parameters: {'n_estimators': 327, 'learning_rate': 0.35225994880763634, 'max_depth': 13, 'l2_leaf_reg': 0.24612038776675235, 'random_strength': 4, 'min_data_in_leaf': 917, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09584112066063405, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.36252538651363}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:39:59,571] Trial 44 finished with value: 0.9875556829202466 and parameters: {'n_estimators': 377, 'learning_rate': 0.30537096716012074, 'max_depth': 15, 'l2_leaf_reg': 0.25740037504900143, 'random_strength': 5, 'min_data_in_leaf': 894, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09607069502493554, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.146264162615185}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:41:06,680] Trial 45 finished with value: 0.9712790870966883 and parameters: {'n_estimators': 369, 'learning_rate': 0.27082479715109115, 'max_depth': 15, 'l2_leaf_reg': 0.23704523022385265, 'random_strength': 17, 'min_data_in_leaf': 946, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09707579827051316, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.592806110703909}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:41:50,185] Trial 46 finished with value: 0.9764833270062904 and parameters: {'n_estimators': 424, 'learning_rate': 0.31181659188715555, 'max_depth': 16, 'l2_leaf_reg': 0.13464070100805153, 'random_strength': 3, 'min_data_in_leaf': 866, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09591563961333538, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.761093909067253}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:42:10,870] Trial 47 finished with value: 0.9878024932009004 and parameters: {'n_estimators': 485, 'learning_rate': 0.283889141322222, 'max_depth': 15, 'l2_leaf_reg': 0.2702970037203994, 'random_strength': 16, 'min_data_in_leaf': 801, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0923229348105018, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.848641892527205}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:43:33,268] Trial 48 finished with value: 0.9680206909130812 and parameters: {'n_estimators': 482, 'learning_rate': 0.23918477328541954, 'max_depth': 15, 'l2_leaf_reg': 0.33319040386923393, 'random_strength': 17, 'min_data_in_leaf': 785, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09996322262357983, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.894853032332353}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:43:58,250] Trial 49 finished with value: 0.9865347984886276 and parameters: {'n_estimators': 592, 'learning_rate': 0.2816821871670607, 'max_depth': 15, 'l2_leaf_reg': 0.3869601996989345, 'random_strength': 32, 'min_data_in_leaf': 856, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09151908404031825, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.985124074937143}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:45:02,731] Trial 50 finished with value: 0.9849267780720512 and parameters: {'n_estimators': 687, 'learning_rate': 0.2825256848732981, 'max_depth': 16, 'l2_leaf_reg': 0.4324431096081254, 'random_strength': 31, 'min_data_in_leaf': 817, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09154420726749535, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.0621765022032355}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:46:02,771] Trial 51 finished with value: 0.9879428126770213 and parameters: {'n_estimators': 703, 'learning_rate': 0.2801303533131502, 'max_depth': 16, 'l2_leaf_reg': 0.3857708890554037, 'random_strength': 27, 'min_data_in_leaf': 806, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09152431054760006, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.146998684680421}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:47:06,108] Trial 52 finished with value: 0.9839112691553694 and parameters: {'n_estimators': 733, 'learning_rate': 0.2684474048663973, 'max_depth': 16, 'l2_leaf_reg': 0.38535305736624337, 'random_strength': 32, 'min_data_in_leaf': 858, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0902552304943831, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.006158055813918}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:47:42,546] Trial 53 finished with value: 0.9850004596992084 and parameters: {'n_estimators': 620, 'learning_rate': 0.24540554113730012, 'max_depth': 15, 'l2_leaf_reg': 0.4292250069107332, 'random_strength': 28, 'min_data_in_leaf': 876, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0911847467049085, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.47129086486794}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:48:08,365] Trial 54 finished with value: 0.981624450956026 and parameters: {'n_estimators': 639, 'learning_rate': 0.24082891307321533, 'max_depth': 15, 'l2_leaf_reg': 0.45712977033019797, 'random_strength': 11, 'min_data_in_leaf': 892, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0845668882940672, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.6362295042261445}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:50:27,335] Trial 55 finished with value: 0.9718842032522979 and parameters: {'n_estimators': 718, 'learning_rate': 0.2250774402904694, 'max_depth': 15, 'l2_leaf_reg': 0.37190953273722266, 'random_strength': 26, 'min_data_in_leaf': 939, 'objective': 'Logloss', 'colsample_bylevel': 0.09245598342045716, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.144432335169316}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:50:39,031] Trial 56 finished with value: 0.9819854445884506 and parameters: {'n_estimators': 581, 'learning_rate': 0.25484636451010506, 'max_depth': 14, 'l2_leaf_reg': 0.3299370997489787, 'random_strength': 36, 'min_data_in_leaf': 691, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08377156848215296, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.027798369690346}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:51:27,760] Trial 57 finished with value: 0.9850840582246121 and parameters: {'n_estimators': 595, 'learning_rate': 0.20896138800375189, 'max_depth': 16, 'l2_leaf_reg': 0.49614664329176433, 'random_strength': 46, 'min_data_in_leaf': 765, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08921869481337513, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.391416188406515}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:52:55,495] Trial 58 finished with value: 0.9828935358876792 and parameters: {'n_estimators': 611, 'learning_rate': 0.2107571285322264, 'max_depth': 16, 'l2_leaf_reg': 0.5068706709963929, 'random_strength': 43, 'min_data_in_leaf': 764, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09890095975242448, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.372732171793697}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:54:03,501] Trial 59 finished with value: 0.9860033639601753 and parameters: {'n_estimators': 874, 'learning_rate': 0.1853738749882392, 'max_depth': 16, 'l2_leaf_reg': 0.30419653757803783, 'random_strength': 49, 'min_data_in_leaf': 829, 'objective': 'Logloss', 'colsample_bylevel': 0.08871046774172554, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.421518281755031}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:55:24,423] Trial 60 finished with value: 0.9693861643884368 and parameters: {'n_estimators': 856, 'learning_rate': 0.1793898936846642, 'max_depth': 14, 'l2_leaf_reg': 0.287175552603269, 'random_strength': 9, 'min_data_in_leaf': 830, 'objective': 'Logloss', 'colsample_bylevel': 0.08526811543313287, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.715350546999073}. Best is trial 29 with value: 0.9892593504301895.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:55:58,123] Trial 61 finished with value: 0.9897682634046807 and parameters: {'n_estimators': 492, 'learning_rate': 0.2010287106803271, 'max_depth': 16, 'l2_leaf_reg': 0.3431251283432695, 'random_strength': 56, 'min_data_in_leaf': 813, 'objective': 'Logloss', 'colsample_bylevel': 0.08799576353512331, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.3342908969900495}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:56:47,737] Trial 62 finished with value: 0.9860975281528692 and parameters: {'n_estimators': 495, 'learning_rate': 0.15641459825466647, 'max_depth': 16, 'l2_leaf_reg': 0.2761230878107502, 'random_strength': 53, 'min_data_in_leaf': 816, 'objective': 'Logloss', 'colsample_bylevel': 0.0937315673547703, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.645826175708752}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:57:16,298] Trial 63 finished with value: 0.9874412215246 and parameters: {'n_estimators': 486, 'learning_rate': 0.2858544848713894, 'max_depth': 15, 'l2_leaf_reg': 0.34880279248099033, 'random_strength': 54, 'min_data_in_leaf': 805, 'objective': 'Logloss', 'colsample_bylevel': 0.09337648129884242, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.2242577974782884}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:57:35,705] Trial 64 finished with value: 0.9803591659573458 and parameters: {'n_estimators': 474, 'learning_rate': 0.2822755671317376, 'max_depth': 15, 'l2_leaf_reg': 0.3431343733373058, 'random_strength': 13, 'min_data_in_leaf': 799, 'objective': 'Logloss', 'colsample_bylevel': 0.08183314238676155, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:57:51,153] Trial 65 finished with value: 0.9845185169806955 and parameters: {'n_estimators': 415, 'learning_rate': 0.32124384802851014, 'max_depth': 15, 'l2_leaf_reg': 0.36695846938003784, 'random_strength': 39, 'min_data_in_leaf': 699, 'objective': 'Logloss', 'colsample_bylevel': 0.08678624176196938, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.325333138547244}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:58:08,507] Trial 66 finished with value: 0.9817857164041437 and parameters: {'n_estimators': 513, 'learning_rate': 0.33685505521363457, 'max_depth': 14, 'l2_leaf_reg': 0.31721875647343484, 'random_strength': 53, 'min_data_in_leaf': 859, 'objective': 'Logloss', 'colsample_bylevel': 0.09830533996436984, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.997794119247824}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:58:46,274] Trial 67 finished with value: 0.9890021598448293 and parameters: {'n_estimators': 465, 'learning_rate': 0.2962780334006957, 'max_depth': 16, 'l2_leaf_reg': 0.27789369283530074, 'random_strength': 8, 'min_data_in_leaf': 672, 'objective': 'Logloss', 'colsample_bylevel': 0.09346614850205906, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.496718953807109}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:59:35,885] Trial 68 finished with value: 0.9834921643528474 and parameters: {'n_estimators': 453, 'learning_rate': 0.2972252364885656, 'max_depth': 16, 'l2_leaf_reg': 0.2768908109080768, 'random_strength': 7, 'min_data_in_leaf': 677, 'objective': 'Logloss', 'colsample_bylevel': 0.09742992912543694, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.412470965349593}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 11:59:38,967] Trial 69 finished with value: 0.9788796944928035 and parameters: {'n_estimators': 413, 'learning_rate': 0.31815766893283687, 'max_depth': 9, 'l2_leaf_reg': 0.20528773366191153, 'random_strength': 13, 'min_data_in_leaf': 154, 'objective': 'Logloss', 'colsample_bylevel': 0.09430652818136478, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# ...
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:03:07,191] Trial 77 finished with value: 0.9697969278746771 and parameters: {'n_estimators': 432, 'learning_rate': 0.31065686186416075, 'max_depth': 8, 'l2_leaf_reg': 0.30753532474636286, 'random_strength': 6, 'min_data_in_leaf': 719, 'objective': 'Logloss', 'colsample_bylevel': 0.08622058057182742, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.957351933054705}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:04:08,572] Trial 78 finished with value: 0.979680553537163 and parameters: {'n_estimators': 501, 'learning_rate': 0.25893961762682105, 'max_depth': 16, 'l2_leaf_reg': 0.3512676374714785, 'random_strength': 30, 'min_data_in_leaf': 929, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09983580544113402, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.879601519970991}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:05:13,289] Trial 79 finished with value: 0.9546006251909234 and parameters: {'n_estimators': 396, 'learning_rate': 0.2914297176552508, 'max_depth': 15, 'l2_leaf_reg': 0.3933788659415511, 'random_strength': 72, 'min_data_in_leaf': 615, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09355450151859447, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:05:39,620] Trial 80 finished with value: 0.9863562943201938 and parameters: {'n_estimators': 649, 'learning_rate': 0.34426242732983575, 'max_depth': 16, 'l2_leaf_reg': 0.1965666619568609, 'random_strength': 1, 'min_data_in_leaf': 671, 'objective': 'Logloss', 'colsample_bylevel': 0.07881820855118714, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.410697191630598}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:06:08,879] Trial 81 finished with value: 0.982042814308212 and parameters: {'n_estimators': 718, 'learning_rate': 0.30272186986842464, 'max_depth': 16, 'l2_leaf_reg': 0.19243152897698512, 'random_strength': 4, 'min_data_in_leaf': 667, 'objective': 'Logloss', 'colsample_bylevel': 0.0790586471956686, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.326648326399804}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:06:41,128] Trial 82 finished with value: 0.9784714334014479 and parameters: {'n_estimators': 602, 'learning_rate': 0.33816045013636853, 'max_depth': 15, 'l2_leaf_reg': 0.13427980199510256, 'random_strength': 12, 'min_data_in_leaf': 768, 'objective': 'Logloss', 'colsample_bylevel': 0.09029693924795011, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.825651648847465}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:07:22,471] Trial 83 finished with value: 0.9802932695587183 and parameters: {'n_estimators': 665, 'learning_rate': 0.27007038257777405, 'max_depth': 16, 'l2_leaf_reg': 0.16232392859641404, 'random_strength': 9, 'min_data_in_leaf': 592, 'objective': 'Logloss', 'colsample_bylevel': 0.08331391106442135, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.606920948308014}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:08:10,176] Trial 84 finished with value: 0.9843908021602897 and parameters: {'n_estimators': 765, 'learning_rate': 0.3215726938511704, 'max_depth': 15, 'l2_leaf_reg': 0.2289462029553812, 'random_strength': 1, 'min_data_in_leaf': 881, 'objective': 'Logloss', 'colsample_bylevel': 0.09579977560742665, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.289542228362994}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:08:18,352] Trial 85 finished with value: 0.9811109039169339 and parameters: {'n_estimators': 630, 'learning_rate': 0.28674677665422477, 'max_depth': 14, 'l2_leaf_reg': 0.20596575084906976, 'random_strength': 19, 'min_data_in_leaf': 804, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.07505222545952613, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.547366896936344}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:09:01,201] Trial 86 finished with value: 0.9880417036156084 and parameters: {'n_estimators': 697, 'learning_rate': 0.30123191446251724, 'max_depth': 16, 'l2_leaf_reg': 0.25297520776499816, 'random_strength': 15, 'min_data_in_leaf': 536, 'objective': 'Logloss', 'colsample_bylevel': 0.08710774082415719, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.818472196707806}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:09:37,883] Trial 87 finished with value: 0.9778569564353441 and parameters: {'n_estimators': 790, 'learning_rate': 0.23093964405134998, 'max_depth': 15, 'l2_leaf_reg': 0.2680967284822773, 'random_strength': 57, 'min_data_in_leaf': 473, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08725230887544572, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.786067616489184}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:10:40,550] Trial 88 finished with value: 0.9854706318936345 and parameters: {'n_estimators': 693, 'learning_rate': 0.2511489103370005, 'max_depth': 16, 'l2_leaf_reg': 0.35536668452323505, 'random_strength': 18, 'min_data_in_leaf': 534, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09174080489645282, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.198131173891937}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:10:43,569] Trial 89 finished with value: 0.9748586239571501 and parameters: {'n_estimators': 145, 'learning_rate': 0.3071012824076375, 'max_depth': 15, 'l2_leaf_reg': 0.3200361579546201, 'random_strength': 15, 'min_data_in_leaf': 363, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09456924222270036, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.155169625397883}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:10:44,942] Trial 90 finished with value: 0.9416664874828353 and parameters: {'n_estimators': 237, 'learning_rate': 0.2727902682123024, 'max_depth': 7, 'l2_leaf_reg': 0.2562424294632717, 'random_strength': 41, 'min_data_in_leaf': 246, 'objective': 'Logloss', 'colsample_bylevel': 0.08907326547769591, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.221568039721063}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:11:07,346] Trial 91 finished with value: 0.9869725322308459 and parameters: {'n_estimators': 647, 'learning_rate': 0.29606553915873923, 'max_depth': 16, 'l2_leaf_reg': 0.22977967748631012, 'random_strength': 49, 'min_data_in_leaf': 568, 'objective': 'Logloss', 'colsample_bylevel': 0.0791898953902148, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.815738341041893}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:11:36,891] Trial 92 finished with value: 0.9760848901318891 and parameters: {'n_estimators': 572, 'learning_rate': 0.3252963651422623, 'max_depth': 16, 'l2_leaf_reg': 0.2909679866993573, 'random_strength': 34, 'min_data_in_leaf': 634, 'objective': 'Logloss', 'colsample_bylevel': 0.08397203949234384, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.675687842176917}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:12:36,939] Trial 93 finished with value: 0.9805423968716728 and parameters: {'n_estimators': 693, 'learning_rate': 0.2645361472691324, 'max_depth': 16, 'l2_leaf_reg': 0.2239212656707625, 'random_strength': 51, 'min_data_in_leaf': 558, 'objective': 'Logloss', 'colsample_bylevel': 0.09085797078694553, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.018119597494563}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:13:23,862] Trial 94 finished with value: 0.9802895623070376 and parameters: {'n_estimators': 753, 'learning_rate': 0.29970146867644837, 'max_depth': 16, 'l2_leaf_reg': 0.32801854051418733, 'random_strength': 67, 'min_data_in_leaf': 832, 'objective': 'Logloss', 'colsample_bylevel': 0.08794266076246747, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.144059917703533}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:13:34,246] Trial 95 finished with value: 0.986215233393737 and parameters: {'n_estimators': 535, 'learning_rate': 0.3138642632916214, 'max_depth': 14, 'l2_leaf_reg': 0.24821899412615486, 'random_strength': 47, 'min_data_in_leaf': 485, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08045201045492043, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.547590099347136}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:14:57,354] Trial 96 finished with value: 0.9721407450686138 and parameters: {'n_estimators': 446, 'learning_rate': 0.2890301330092035, 'max_depth': 15, 'l2_leaf_reg': 0.2959809668911419, 'random_strength': 24, 'min_data_in_leaf': 443, 'objective': 'Logloss', 'colsample_bylevel': 0.09273639458209512, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.736605040576036}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:15:44,493] Trial 97 finished with value: 0.9813182319671865 and parameters: {'n_estimators': 488, 'learning_rate': 0.37097808970819585, 'max_depth': 15, 'l2_leaf_reg': 0.17408120046791045, 'random_strength': 21, 'min_data_in_leaf': 568, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09720442764339488, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.9892250170405985}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:16:26,306] Trial 98 finished with value: 0.9796413493506376 and parameters: {'n_estimators': 558, 'learning_rate': 0.2771206160012421, 'max_depth': 16, 'l2_leaf_reg': 0.26624245705956284, 'random_strength': 59, 'min_data_in_leaf': 778, 'objective': 'Logloss', 'colsample_bylevel': 0.08457905583032319, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 61 with value: 0.9897682634046807.
# <ipython-input-29-db8321be8fb3>:29: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "auc")
# [I 2023-03-17 12:17:00,877] Trial 99 finished with value: 0.9907584703286404 and parameters: {'n_estimators': 594, 'learning_rate': 0.24834787276073994, 'max_depth': 15, 'l2_leaf_reg': 0.23433495849542968, 'random_strength': 29, 'min_data_in_leaf': 715, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09612312625177241, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.702265065469754}. Best is trial 99 with value: 0.9907584703286404.

# %%
print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Best trial:
#   Value: 0.9907584703286404
#   Params:
#     n_estimators: 594
#     learning_rate: 0.24834787276073994
#     max_depth: 15
#     l2_leaf_reg: 0.23433495849542968
#     random_strength: 29
#     min_data_in_leaf: 715
#     objective: CrossEntropy
#     colsample_bylevel: 0.09612312625177241
#     boosting_type: Plain
#     bootstrap_type: Bayesian
#     bagging_temperature: 7.702265065469754

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
best_cat_model = CatBoostClassifier(**trial.params, verbose=False)
best_cat_model.fit(X_train, y_train, cat_features=cat_cols)
# preds = best_cat_model.predict_proba(X_test)[:, 1]
# score = roc_auc_score(y_test, preds)

# %%
# print(score)

# %%
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
PARAMS = {
    "min_samples_split": [9],  # range(2, 200),
    "min_samples_leaf": [18],  # range(1, 200),
}
clf = RandomForestClassifier(n_estimators=200, random_state=42)

grid_search = GridSearchCV(clf, PARAMS, scoring="roc_auc", cv=5)
rf = grid_search.fit(X_train, y_train);

# %%
numeric_transformer = Pipeline(steps=[
    ("scaler", StandardScaler())
])
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, num_cols),
        ("cat", OneHotEncoder(handle_unknown='ignore'), cat_cols)
    ]
)
PARAMS = {
    "model__n_neighbors": [44],  # range(1, 100),
    "model__metric": ["manhattan"],  # ["cityblock", "cosine", "euclidean", "l1", "l2", "manhattan", "nan_euclidean"],
}

clf = Pipeline(steps=[
    ("preproc", preprocessor),
    ("model", KNeighborsClassifier()),
])
    
grid_search = GridSearchCV(
    estimator=clf,
    param_grid=PARAMS,
    scoring="roc_auc",
    n_jobs=-1,
    cv=10,
    refit=True,
)
knn = grid_search.fit(X_train, y_train)

# %%
meta = CatBoostClassifier(**trial.params, verbose=False)
stacking = StackingClassifier(
    estimators=[
        ("logreg", logreg),
        ("knn", knn),
        ("rf", rf),
        ("catboost", best_cat_model),
    ],
    final_estimator=meta,
    n_jobs=-1,
)

# stacking.fit(X_patterns_train, y_patterns_train)
stacking.fit(X_train, y_train)
# Out:
# StackingClassifier(estimators=[('logreg',
#                                 GridSearchCV(cv=5,
#                                              estimator=Pipeline(steps=[('preprocess',
#                                                                         ColumnTransformer(transformers=[('num',
#                                                                                                          Pipeline(steps=[('scaler',
#                                                                                                                           StandardScaler())]),
#                                                                                                          ['ClientPeriod',
#                                                                                                           'MonthlySpending',
#                                                                                                           'TotalSpent'])])),
#                                                                        ('model',
#                                                                         LogisticRegression(max_iter=3000))]),
#                                              param_grid={'model__C': [0.001,
#                                                                       0.01, 0.1,
#                                                                       1, 10,
#                                                                       100,
#                                                                       1000],
#                                                          'model__penalt...
#                                                          'model__n_neighbors': [44]},
#                                              scoring='roc_auc')),
#                                ('rf',
#                                 GridSearchCV(cv=5,
#                                              estimator=RandomForestClassifier(n_estimators=200,
#                                                                               random_state=42),
#                                              param_grid={'min_samples_leaf': [18],
#                                                          'min_samples_split': [9]},
#                                              scoring='roc_auc')),
#                                ('catboost',
#                                 <catboost.core.CatBoostClassifier object at 0x7f0adade9ee0>)],
#                    final_estimator=<catboost.core.CatBoostClassifier object at 0x7f0ada915b50>,
#                    n_jobs=-1)

# %%
# stacking_preds = stacking.predict_proba(X_patterns_test)[:, 1]
# stacking_score = roc_auc_score(y_patterns_test, stacking_preds)

# print(stacking_score)

# %% [markdown]
# Выпишите, какое лучшее качество и с какими параметрами вам удалось получить

# %% [markdown]
# ВАШ ОТВЕТ

# %% [markdown]
# # Предсказания

# %%
X_test = pd.read_csv('./test.csv')

X_test = X_test.replace(patterns)

# # Заменяем пустые ячейки в Total Spent на NaN
X_test['TotalSpent'].replace(' ', 0, inplace=True)
# print(X_test.shape)
# # Удаляем NaN из датасета
# # X_test.dropna(inplace=True)
# print(X_test.shape)

# %%
best_model = stacking 
# best_model = best_cat_model
best_pred = best_model.predict_proba(X_test)[:, 1]

# %%
# X_test = pd.read_csv('./test.csv')
submission = pd.read_csv('./submission.csv', index_col = 'Id')

# submission['Churn'] = best_pred
submission['Churn'] = best_pred
submission.to_csv('./my_submission.csv')

# %% [markdown]
# Лучшее решение отправьте в Stepik.
